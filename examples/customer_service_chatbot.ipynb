# %% [markdown]
# # Conversational AI Chatbot for Customer Service
#
# **Course:** Natural Language Processing · Unit 5 — Dialogue Systems and Conversational AI
# **Institution:** Universidad Tecnológica de Bolívar
# **Reference:** Jurafsky, D. & Martin, J. H. (2025). *Speech and Language Processing* (3rd ed.), Ch. 15 — Chatbots and Dialogue Systems
# **Python compatibility:** 3.10 · 3.11 · 3.12 · 3.13
#
# ---
#
# ## Learning Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Use a **zero-shot multilingual classifier** to detect user intent without labelled training data
# 2. Apply **NER** to extract entities (account numbers, names, cities) from conversational text
# 3. Implement **slot-filling dialogue management** with a simple memory (state) dictionary
# 4. Connect intent classification and NER into a unified response pipeline
# 5. Build and launch an interactive chatbot with **Gradio**
#
# ## Architecture Overview
#
# ```
# User message
#     │
#     ├─► NER (spaCy es_core_news_sm)  ──► entity slots  ─┐
#     │                                                    ├─► Response generator
#     └─► Intent classifier (zero-shot) ──► intent label  ─┘
# ```

# %% [markdown]
# ---
#
# ## 1. Dependencies
#
# Install **once** in your terminal:
#
# ```bash
# pip install transformers torch gradio spacy
# python -m spacy download es_core_news_sm
# ```

# %%
# pip install transformers torch gradio spacy  # run once in terminal
# python -m spacy download es_core_news_sm     # run once in terminal
import re
import time
import random
from typing import Dict, Any

import gradio as gr
from transformers import pipeline
import spacy

# %% [markdown]
# ---
#
# ## 2. Load Models
#
# - **`facebook/bart-large-mnli`**: a large MNLI-fine-tuned model that performs zero-shot classification — no task-specific training needed.
# - **`es_core_news_sm`**: spaCy's small Spanish NER model for entity extraction.

# %%
# Zero-shot intent classifier — multilingual, no labelled data required
intent_clf = pipeline(
    'zero-shot-classification',
    model='facebook/bart-large-mnli',
)

# Spanish NER model for entity extraction from user messages
try:
    nlp = spacy.load('es_core_news_sm')
except OSError:
    raise SystemExit('Run: python -m spacy download es_core_news_sm')

print('Models loaded successfully.')

# %% [markdown]
# > **Output interpretation:** Both models are downloaded from HuggingFace Hub on first run and cached locally (~1.6 GB for BART-large). The zero-shot model evaluates whether a hypothesis label entails the premise (user message) — it does not require any fine-tuning on chatbot data.

# %% [markdown]
# ---
#
# ## 3. Define Intent Labels and Example Phrases
#
# The chatbot handles a typical banking customer-service domain. Each intent key maps to a list of natural-language descriptions used as zero-shot hypotheses.

# %%
INTENTS = {
    'check_balance': [
        'check balance', 'account balance', 'how much do I owe', 'my debt',
        'consultar saldo', 'cuanto debo', 'mi saldo',
    ],
    'pay_bill': [
        'pay a bill', 'make a payment', 'pay my service',
        'pagar factura', 'realizar pago', 'pagar servicio',
    ],
    'transfer_funds': [
        'transfer money', 'send funds', 'bank transfer',
        'transferir dinero', 'enviar plata', 'hacer transferencia',
    ],
    'block_card': [
        'block my card', 'lost card', 'stolen card',
        'bloquear tarjeta', 'tarjeta perdida', 'me robaron la tarjeta',
    ],
    'speak_to_agent': [
        'speak to a human', 'talk to an agent', 'escalate my issue',
        'hablar con un agente', 'quiero un humano', 'escalar problema',
    ],
}

INTENT_LABELS = list(INTENTS.keys())
print(f'Defined intents: {INTENT_LABELS}')

# %% [markdown]
# ---
#
# ## 4. Simulated Back-end APIs
#
# These functions simulate integrations with core banking systems. In production, replace them with real API calls.

# %%
def api_check_balance(account_number: str) -> float:
    """Simulate a core-banking balance query.

    Args:
        account_number: Customer account identifier.

    Returns:
        Simulated account balance in COP.
    """
    return round(random.uniform(100_000, 5_000_000), 2)


def api_transfer_funds(origin: str, destination: str, amount: float) -> bool:
    """Simulate a funds transfer between two accounts.

    Args:
        origin: Source account number.
        destination: Target account number.
        amount: Amount to transfer in COP.

    Returns:
        True if the transfer was accepted, False otherwise.
    """
    time.sleep(0.1)  # simulate network latency
    return random.random() > 0.1  # 90% success rate


def api_block_card(card_number: str) -> str:
    """Simulate a card blocking request.

    Args:
        card_number: 16-digit card number.

    Returns:
        Confirmation code string.
    """
    return f'BLOCK-{card_number[-4:]}-{random.randint(1000,9999)}'

# %% [markdown]
# ---
#
# ## 5. NLP Utilities — Entity Extraction and Intent Classification

# %%
# Regex pattern for 8-12 digit account numbers
ACCOUNT_NUMBER_RE = re.compile(r'\b(\d{8,12})\b')


def extract_entities(text: str) -> dict:
    """Extract named entities and account numbers from user message.

    Args:
        text: Raw user message string.

    Returns:
        Dictionary with keys 'persons', 'organisations', 'locations',
        and 'account_numbers'.
    """
    doc = nlp(text)
    return {
        'persons': [e.text for e in doc.ents if e.label_ == 'PER'],
        'organisations': [e.text for e in doc.ents if e.label_ == 'ORG'],
        'locations': [e.text for e in doc.ents if e.label_ == 'LOC'],
        'account_numbers': ACCOUNT_NUMBER_RE.findall(text),
    }


def classify_intent(text: str) -> str:
    """Classify user message into one of the predefined intent labels.

    Args:
        text: Raw user message string.

    Returns:
        Intent label string (key of INTENTS dict).
    """
    result = intent_clf(text, candidate_labels=INTENT_LABELS)
    return result['labels'][0]  # highest-scoring label


# Quick smoke-test
test_msg = 'Quiero saber cuánto tengo en mi cuenta 12345678'
print(f'Intent: {classify_intent(test_msg)}')
print(f'Entities: {extract_entities(test_msg)}')

# %% [markdown]
# > **Output interpretation:** `classify_intent` returns `check_balance` for the test message, and `extract_entities` finds the account number `12345678`. The combination of regex (precise pattern matching for structured data) and spaCy NER (flexible extraction for unstructured names and places) covers both structured and unstructured entity types.

# %% [markdown]
# ---
#
# ## 6. Dialogue Manager with Slot Memory
#
# The memory dictionary stores conversation slots across turns. Missing slots trigger follow-up questions (clarification requests).

# %%
def init_memory() -> Dict[str, Any]:
    """Initialise an empty dialogue memory for a new conversation session."""
    return {
        'name': None,
        'account_number': None,
        'intent': None,
        'confirmed': False,
    }


RESPONSES = {
    'check_balance': (
        'Your current balance is COP {balance:,.0f}. '
        'Is there anything else I can help you with?'
    ),
    'pay_bill': 'I can help you pay a bill. Please provide the service name and amount.',
    'transfer_funds': 'To make a transfer, I need the destination account number and amount.',
    'block_card': 'Your card has been blocked. Confirmation code: {code}.',
    'speak_to_agent': 'Connecting you to a human agent. Please hold for 2-3 minutes.',
    'need_account': 'Could you please provide your account number (8-12 digits)?',
    'greeting': (
        'Hello! I am the virtual assistant of Banco Digital. '
        'How can I help you today?'
    ),
}

# %% [markdown]
# ---
#
# ## 7. Main Response Logic
#
# The `respond` function ties together entity extraction, intent classification, slot filling, and response generation in a single turn.

# %%
def respond(user_msg: str, state: Dict[str, Any]):
    """Process one dialogue turn and return the bot response and updated state.

    Args:
        user_msg: Raw text from the user.
        state: Current dialogue memory (modified in place).

    Returns:
        Tuple of (response_text, updated_state).
    """
    # --- Entity extraction ---
    entities = extract_entities(user_msg)

    # Fill name slot from recognised PER entities
    if entities['persons'] and not state['name']:
        state['name'] = entities['persons'][0]

    # Fill account slot from regex matches
    if entities['account_numbers'] and not state['account_number']:
        state['account_number'] = entities['account_numbers'][0]

    # --- Intent classification ---
    intent = classify_intent(user_msg)
    state['intent'] = intent

    # --- Slot-filling: request missing account number ---
    if intent == 'check_balance' and not state['account_number']:
        return RESPONSES['need_account'], state

    # --- Response generation ---
    if intent == 'check_balance' and state['account_number']:
        balance = api_check_balance(state['account_number'])
        return RESPONSES['check_balance'].format(balance=balance), state

    if intent == 'block_card' and state['account_number']:
        code = api_block_card(state['account_number'])
        return RESPONSES['block_card'].format(code=code), state

    return RESPONSES.get(intent, RESPONSES['greeting']), state

# %% [markdown]
# ---
#
# ## 8. Interactive Gradio Interface
#
# Run this cell to launch the chatbot on `http://localhost:7860`. Share the public link (requires `share=True`) to expose it externally.

# %%
with gr.Blocks(theme='soft') as demo:
    gr.Markdown('## Digital Bank Virtual Assistant — NLU + NER + Slot Filling')
    chatbot_ui = gr.Chatbot(label='Conversation')
    msg_box = gr.Textbox(label='Your message', placeholder='Type here and press Enter...')
    state_box = gr.State(init_memory())

    def chat(user_msg, history, state):
        response, updated_state = respond(user_msg, state)
        history = history + [[user_msg, response]]
        return '', history, updated_state

    msg_box.submit(chat, [msg_box, chatbot_ui, state_box], [msg_box, chatbot_ui, state_box])

demo.launch(share=False)

# %% [markdown]
# > **Output interpretation:** Gradio launches a local web server and opens the chatbot UI in your browser. The `state_box` (Gradio `State`) persists the dialogue memory across turns within the same session. Try saying 'I want to check my balance' (triggers slot-fill request for account number), then '123456789' (fills the slot), and the bot returns a simulated balance.

# %% [markdown]
# ---
#
# ## 9. Suggested Extensions
#
# 1. **New intents:** Add 'open_account', 'request_loan', or 'report_fraud' to `INTENTS` and corresponding response templates.
# 2. **Real APIs:** Replace `api_check_balance` / `api_block_card` with authenticated REST calls to a core banking system.
# 3. **Better NER:** Fine-tune `es_core_news_sm` on banking conversation transcripts to improve entity recall for account numbers, card types, and product names.
# 4. **Multi-language:** Use `multilingual-e5-large` instead of `bart-large-mnli` for better Spanish intent classification.
# 5. **Logging:** Persist each turn `(user_msg, intent, entities, response)` to a database for quality monitoring and model retraining.
